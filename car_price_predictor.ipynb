# %%
import pandas as pd

# %%
car=pd.read_csv("quikr_car.csv")

# %%
# see random values from dataset
car.sample(5)
# Out:
#                                  name    company  year     Price  kms_driven  \
# 203  Maruti Suzuki Wagon R LXi BS III     Maruti  2009  1,35,000  45,000 kms
# 818               Maruti Suzuki Dzire     Maruti  2014  3,74,999  33,000 kms
# 424            Chevrolet Spark LS 1.0  Chevrolet  2010    95,000  23,000 kms
# 208     Maruti Suzuki Alto LXi BS III     Maruti  2010  1,35,000  34,580 kms
# 601     Maruti Suzuki Wagon R AX BSIV     Maruti  2010  2,25,000  40,000 kms
#
#     fuel_type
# 203    Petrol
# 818    Petrol
# 424    Petrol
# 208    Petrol
# 601    Petrol

# %%
car.shape
# Out:
# (892, 6)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB
